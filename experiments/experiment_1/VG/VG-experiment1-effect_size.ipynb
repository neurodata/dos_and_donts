# %%
import numpy as np
from scipy.stats import ttest_ind

from src.simulations import IndependentEdge

# %%
ie = IndependentEdge(sample_size=100, n_vertices=10, epsilon=0.001, delta=0.05)
x, y = ie._sample()

# %%
def cohen_d(x, y):

    mean = np.mean(x) - np.mean(y)
    var = np.sqrt((np.std(x, ddof=1)**2 + np.std(y, ddof=1)**2) / 2.0)
    
    return mean / var

# %%
c1 = [2, 4, 7, 3, 7, 35, 8, 9]
c2 = [i * 2 for i in c1]

cohen_d(c1, c2)
# Out:
# -0.5567679522645598

# %%
cohen = []

for i in range(10):
    for j in range(10):
        
        xi = x[i, j, :]
        yi = y[i, j, :]
        
        cohen.append(cohen_d(xi, yi))

# %%
for est in cohen:
    if np.isnan(est):
        cohen.remove(est)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

ax = sns.distplot(cohen, bins=50)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-cc2f02c3224c> in <module>
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#       5
# ----> 6 ax = sns.distplot(cohen, bins=50)
#       7 plt.show()
#
# ~/miniconda3/envs/dnd/lib/python3.7/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     229     if kde:
#     230         kde_color = kde_kws.pop("color", color)
# --> 231         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     232         if kde_color != color:
#     233             kde_kws["color"] = kde_color
#
# ~/miniconda3/envs/dnd/lib/python3.7/site-packages/seaborn/distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     689         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     690                                  gridsize, cut, clip, legend, ax,
# --> 691                                  cumulative=cumulative, **kwargs)
#     692
#     693     return ax
#
# ~/miniconda3/envs/dnd/lib/python3.7/site-packages/seaborn/distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     292                               "only implemented in statsmodels."
#     293                               "Please install statsmodels.")
# --> 294         x, y = _scipy_univariate_kde(data, bw, gridsize, cut, clip)
#     295
#     296     # Make sure the density is nonnegative
#
# ~/miniconda3/envs/dnd/lib/python3.7/site-packages/seaborn/distributions.py in _scipy_univariate_kde(data, bw, gridsize, cut, clip)
#     364     """Compute a univariate kernel density estimate using scipy."""
#     365     try:
# --> 366         kde = stats.gaussian_kde(data, bw_method=bw)
#     367     except TypeError:
#     368         kde = stats.gaussian_kde(data)
#
# ~/miniconda3/envs/dnd/lib/python3.7/site-packages/scipy/stats/kde.py in __init__(self, dataset, bw_method, weights)
#     206             self._neff = 1/sum(self._weights**2)
#     207
# --> 208         self.set_bandwidth(bw_method=bw_method)
#     209
#     210     def evaluate(self, points):
#
# ~/miniconda3/envs/dnd/lib/python3.7/site-packages/scipy/stats/kde.py in set_bandwidth(self, bw_method)
#     552             raise ValueError(msg)
#     553
# --> 554         self._compute_covariance()
#     555
#     556     def _compute_covariance(self):
#
# ~/miniconda3/envs/dnd/lib/python3.7/site-packages/scipy/stats/kde.py in _compute_covariance(self)
#     564                                                bias=False,
#     565                                                aweights=self.weights))
# --> 566             self._data_inv_cov = linalg.inv(self._data_covariance)
#     567
#     568         self.covariance = self._data_covariance * self.factor**2
#
# ~/miniconda3/envs/dnd/lib/python3.7/site-packages/scipy/linalg/basic.py in inv(a, overwrite_a, check_finite)
#     943
#     944     """
# --> 945     a1 = _asarray_validated(a, check_finite=check_finite)
#     946     if len(a1.shape) != 2 or a1.shape[0] != a1.shape[1]:
#     947         raise ValueError('expected square matrix')
#
# ~/miniconda3/envs/dnd/lib/python3.7/site-packages/scipy/_lib/_util.py in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     237             raise ValueError('masked arrays are not supported')
#     238     toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 239     a = toarray(a)
#     240     if not objects_ok:
#     241         if a.dtype is np.dtype('O'):
#
# ~/miniconda3/envs/dnd/lib/python3.7/site-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#     496     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#     497         raise ValueError(
# --> 498             "array must not contain infs or NaNs")
#     499     return a
#     500
#
# ValueError: array must not contain infs or NaNs

# %%
iris = sns.load_dataset("iris")
g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_lower(sns.kdeplot, levels=6, cmap="Blues_d")
g.map_upper(plt.scatter, color=iris["species"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/miniconda3/envs/dnd/lib/python3.7/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4218             try:
# -> 4219                 mcolors.to_rgba_array(kwcolor)
#    4220             except ValueError:
#
# ~/miniconda3/envs/dnd/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     285     for i, cc in enumerate(c):
# --> 286         result[i] = to_rgba(cc, alpha)
#     287     return result
#
# ~/miniconda3/envs/dnd/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     176     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 177         rgba = _to_rgba_no_colorcycle(c, alpha)
#     178         try:
#
# ~/miniconda3/envs/dnd/lib/python3.7/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     230             pass
# --> 231         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     232     # tuple color.
#
# ValueError: Invalid RGBA argument: 'setosa'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-4a2afb51c8a6> in <module>
#       3 g.map_diag(sns.kdeplot)
#       4 g.map_lower(sns.kdeplot, levels=6, cmap="Blues_d")
# ----> 5 g.map_upper(plt.scatter, color=iris["species"])
#
# ~/miniconda3/envs/dnd/lib/python3.7/site-packages/seaborn/axisgrid.py in map_upper(self, func, **kwargs)
#    1488                 color = self.palette[k] if kw_color is None else kw_color
#    1489                 func(data_k[x_var], data_k[y_var], label=label_k,
# -> 1490                      color=color, **kwargs)
#    1491
#    1492             self._clean_axis(ax)
#
# ~/miniconda3/envs/dnd/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2839         verts=verts, edgecolors=edgecolors,
#    2840         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2841         None else {}), **kwargs)
#    2842     sci(__ret)
#    2843     return __ret
#
# ~/miniconda3/envs/dnd/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/miniconda3/envs/dnd/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4444             self._parse_scatter_color_args(
#    4445                 c, edgecolors, kwargs, xshape, yshape,
# -> 4446                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4447
#    4448         if plotnonfinite and colors is None:
#
# ~/miniconda3/envs/dnd/lib/python3.7/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4219                 mcolors.to_rgba_array(kwcolor)
#    4220             except ValueError:
# -> 4221                 raise ValueError("'color' kwarg must be an mpl color"
#    4222                                  " spec or sequence of color specs.\n"
#    4223                                  "For a sequence of values to be color-mapped,"
#
# ValueError: 'color' kwarg must be an mpl color spec or sequence of color specs.
# For a sequence of values to be color-mapped, use the 'c' argument instead.
