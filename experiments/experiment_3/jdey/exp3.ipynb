# %%
import numpy as np
from graspy.simulations import sbm
from joblib import Parallel, delayed
from itertools import product
from scipy.stats import ttest_ind
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %%
def generate_data(m=10, n=[5,15], p=0.5, delta=0, seed=None):
    np.random.seed(seed)
    p1 = [[p, p],
          [p, p]]
    p2 = [[p+delta, p],
          [p, p]]
    
    pop1 = []
    pop2 = []
    for i in range(m):
        pop1.append(sbm(n, p1))
        pop2.append(sbm(n, p2))
        
    pop1 = np.stack(pop1)
    pop2 = np.stack(pop2)
    
    return pop1, pop2

# %%
def run_exp(m, n, p, delta, seed, reps):
    pval = []
    stat = []
    power = np.zeros((2,2),dtype=float)
    
    for _ in range(reps):
        pop1_block_mean = np.zeros((m,2,2), dtype=float)
        pop2_block_mean = np.zeros((m,2,2), dtype=float)
        
        pop1, pop2 = generate_data(m, n, p, delta, seed)
        
        pop1_block_mean[:,0,0] = pop1[:,0:n[0],0:n[0]].mean(axis=(1,2))
        pop2_block_mean[:,0,0] = pop2[:,1:n[0],1:n[0]].mean(axis=(1,2))
        pop1_block_mean[:,1,1] = pop1[:,n[0]:n[1],n[0]:n[1]].mean(axis=(1,2))
        pop2_block_mean[:,1,1] = pop2[:,n[0]:n[1],n[0]:n[1]].mean(axis=(1,2))
        pop1_block_mean[:,0,1] = pop1[:,0:n[0],n[0]:n[1]].mean(axis=(1,2))
        pop2_block_mean[:,0,1] = pop2[:,0:n[0],n[0]:n[1]].mean(axis=(1,2))
        pop1_block_mean[:,1,0] = pop1_block_mean[:,0,1]
        pop2_block_mean[:,1,0] = pop2_block_mean[:,0,1]
        
        statistics, pvalue = ttest_ind(pop1_block_mean, pop2_block_mean, axis=0)
        
        power += 1*(pvalue>0.05)
        pval.append(pvalue)
        stat.append(statistics)
     
    pval = sum(pval)/len(pval)
    stat = sum(stat)/len(stat)
    power = power/reps
    
    return [stat, pval, power]

# %%
block_1 = 5 
block_2 = 15
n = [block_1, block_2]
sample_size = np.linspace(10,1000,100,dtype=int)
reps = 2000
p = .5
deltas = np.linspace(0, 1 - p, 100)

# %%
args = [(m, n, p, delta, seed*reps, reps) for seed, (m, delta) in enumerate(product(sample_size, deltas))]

res = Parallel(n_jobs=-2, verbose=1)(
    delayed(run_exp)(
        *arg
    ) for arg in args
)
# Out:
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 47 concurrent workers.
# [Parallel(n_jobs=-2)]: Done 106 tasks      | elapsed:  3.0min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-234-e37b929da2db> in <module>
#       4     delayed(run_exp)(
#       5         *arg
# ----> 6     ) for arg in args
#       7 )
#
# ~/env/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#     932
#     933             with self._backend.retrieval_context():
# --> 934                 self.retrieve()
#     935             # Make sure that we get a last message telling us we are done
#     936             elapsed_time = time.time() - self._start_time
#
# ~/env/lib/python3.6/site-packages/joblib/parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# ~/env/lib/python3.6/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# /usr/lib/python3.6/concurrent/futures/_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
pval = [a[1][0][0] for a in res]
pval
# Out:
# [0.2720516555312569,
#  0.18077453725572779,
#  0.6007719584765621,
#  0.8241007120462838,
#  0.033374286847429185,
#  0.23924832948732566,
#  0.18309135150286898,
#  0.8545910046795909,
#  0.37767264783134863,
#  0.2576800920915403,
#  0.10946605329511766,
#  0.29845767265007717,
#  0.5222603423967184,
#  0.08270288435845054,
#  0.8841724485509094,
#  0.8503252967358128,
#  0.8416666597692222,
#  0.00499717516294734,
#  0.12684794080651807,
#  0.6353238375695582,
#  0.5843724639364827,
#  0.8146211361407633,
#  0.34097368365643627,
#  8.405754746203658e-10,
#  8.928705864006075e-10,
#  6.543931225293717e-09,
#  1.2583050835365903e-13,
#  8.151989569292452e-18,
#  1.4650242879267337e-10,
#  6.465229575046255e-09,
#  6.042075049320818e-11,
#  3.6244549055346453e-12,
#  1.3686145854951553e-15,
#  1.75578710963819e-16,
#  1.6008585585090808e-16,
#  2.828367701634014e-15,
#  4.5664971646907884e-14,
#  8.315449759001845e-15,
#  5.122604195949701e-16,
#  1.9352048374436618e-21,
#  4.957344044603235e-18,
#  1.1676266110293767e-18,
#  1.7915031707492933e-19,
#  8.091597447357424e-18,
#  1.7244328831439128e-20,
#  1.2138216313829847e-28,
#  3.4411937241510554e-29,
#  1.519245232794612e-23,
#  5.071141730217176e-23,
#  2.4105947891324114e-24,
#  1.202907836336735e-30,
#  2.8254477349705884e-29,
#  5.200897989582372e-32,
#  4.559097108866666e-34,
#  1.6802301361976586e-28,
#  3.1760924665974256e-38,
#  1.1549579671649042e-34,
#  1.2831212555950528e-37,
#  2.2018562937042943e-32,
#  1.1336608230318274e-44,
#  6.17404142352691e-40,
#  1.0773635776310047e-40,
#  1.0197239973043728e-43,
#  2.3216735460743393e-44,
#  3.995259332017802e-42,
#  8.33045577955339e-48,
#  1.1694384308210289e-48,
#  3.426788524610674e-51,
#  2.183812941031154e-49,
#  4.448762390671374e-47,
#  1.5287070247584697e-53,
#  7.838673014572555e-53,
#  1.7237132321639428e-46,
#  1.947222092052975e-50,
#  7.265024635215793e-53,
#  7.166800547553162e-49,
#  5.107664563819564e-60,
#  1.3919670764423983e-59,
#  5.7405799599809244e-64,
#  5.580480309465129e-63,
#  2.6673878268720484e-58,
#  1.643381506484932e-67,
#  2.5085606414647498e-64,
#  1.0538233418776412e-75,
#  ...]

# %%
data = { 'p': [a[2] for a in args], 
         'effect size': [a[3] for a in args], 
         'sample size': [a[0] for a in args], 
         'pval': [a[1][0][0] for a in res], 
         'stat': [a[0][0][0] for a in res] }

# %%
res_df = pd.DataFrame(data)
res_df.to_csv('20191217.csv')
res_df.head()
# Out:
#      p  effect size  sample size      pval      stat
# 0  0.5     0.000000           10  0.272052  1.133071
# 1  0.5     0.005051           10  0.180775 -1.392369
# 2  0.5     0.010101           10  0.600772  0.532677
# 3  0.5     0.015152           10  0.824101 -0.225539
# 4  0.5     0.020202           10  0.033374  2.303743

# %%
df1 = pd.pivot_table(res_df,
                    index='sample size',
                    values='pval',
                    columns='effect size')

df2 = pd.pivot_table(res_df,
                    index='sample size',
                    values='stat',
                    columns='effect size')
df2.head()
# Out:
# effect size  0.000000  0.005051  0.010101  0.015152  0.020202  0.025253  \
# sample size
# 10           1.133071 -1.392369  0.532677 -0.225539  2.303743  1.217195
# 20           0.302742 -1.474902  0.518306  0.421797  2.094395  1.526976
# 30           0.933446 -0.802526 -0.063769  0.290110 -2.140423 -0.549675
# 40           0.127656  0.461773  1.624478  1.434285  0.554778 -0.263212
# 50           2.071884 -1.077587 -0.418624  0.688025  1.867455  0.401066
#
# effect size  0.030303  0.035354  0.040404  0.045455  ...   0.454545  \
# sample size                                          ...
# 10           1.384628 -0.185914 -0.904510 -1.168929  ...  -9.855842
# 20          -0.843184 -1.196624 -1.558800  0.437619  ...  -8.700846
# 30           1.925606 -0.316472  1.229617 -1.838333  ... -12.412606
# 40          -0.032052 -0.959744  1.463861  0.745750  ... -12.608476
# 50           0.394234  0.669162 -1.001164  0.063995  ... -18.535278
#
# effect size   0.459596   0.464646   0.469697   0.474747   0.479798   0.484848  \
# sample size
# 10          -14.272539  -9.806827 -10.000300  -8.071795  -6.595535 -11.092650
# 20          -10.748918  -7.853130  -9.557730 -12.190188 -15.627265 -12.268105
# 30          -16.900210 -12.329049 -12.681364 -12.426608 -13.246400 -11.594192
# 40          -13.487816 -13.893796 -15.806145 -13.537883 -17.080526 -18.082143
# 50          -13.356723 -11.482141 -19.494629 -18.590346 -17.691963 -18.551594
#
# effect size   0.489899   0.494949   0.500000
# sample size
# 10           -6.602886  -6.263057  -8.507748
# 20          -12.933709 -11.436822 -17.161248
# 30          -14.168389 -15.018531 -12.249205
# 40          -15.201576 -16.447380 -17.837928
# 50          -18.014165 -22.114967 -20.421676
#
# [5 rows x 100 columns]

# %%
sns.set(font_scale=1.4)
ax = sns.heatmap(
        df,
        square=True,
        center=0,
        cmap="RdBu_r",
        cbar_kws = dict(shrink=0.7),
        xticklabels= 10,#[fmt(i) for i in np.linspace(0, 1 - p, 101)[::10]],
        yticklabels=10,
        vmin=0, 
        vmax=1
    )
ax.invert_yaxis()

fmt = '{:0.2f}'
xticklabels = []
for item in ax.get_xticklabels():
    item.set_text(fmt.format(float(item.get_text())))
    xticklabels += [item]
yticklabels = []
for item in ax.get_yticklabels():
    item.set_text(fmt.format(float(item.get_text())))
    yticklabels += [item]
ax.set_title('P value') 
ax.set_xticklabels(xticklabels)
#ax.set_yticklabels(yticklabels)
# Out:
# [Text(0.5, 0, '0.00'),
#  Text(10.5, 0, '0.05'),
#  Text(20.5, 0, '0.10'),
#  Text(30.5, 0, '0.15'),
#  Text(40.5, 0, '0.20'),
#  Text(50.5, 0, '0.25'),
#  Text(60.5, 0, '0.30'),
#  Text(70.5, 0, '0.35'),
#  Text(80.5, 0, '0.40'),
#  Text(90.5, 0, '0.45')]

# %%
sns.set(font_scale=1.4)
ax = sns.heatmap(
        df2,
        square=True,
        center=0,
        cmap="RdBu_r",
        cbar_kws = dict(shrink=0.7),
        xticklabels= 20,#[fmt(i) for i in np.linspace(0, 1 - p, 101)[::10]],
        yticklabels=100
    )
ax.invert_yaxis()

fmt = '{:0.2f}'
xticklabels = []
for item in ax.get_xticklabels():
    item.set_text(fmt.format(float(item.get_text())))
    xticklabels += [item]
yticklabels = []
for item in ax.get_yticklabels():
    item.set_text(fmt.format(float(item.get_text())))
    yticklabels += [item]
    
ax.set_xticklabels(xticklabels)
ax.set_title('Test statistics')
#ax.set_yticklabels(yticklabels)
# Out:
# Text(0.5, 1, 'Test statistics')

# %%
'{:0.2f}'.format(2.34455)
# Out:
# '2.34'

# %%
1*(res[0][1]<0)
# Out:
# array([[0, 0],
#        [0, 0]])
